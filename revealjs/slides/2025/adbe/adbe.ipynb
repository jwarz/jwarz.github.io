# %% [raw]
# ---
# # TITLE & AUTHOR
# title: "Explore new ways to create"
# subtitle: "Generate images, audio, and now — video"
# author: "Joschka Schwarz"
# institute: "Sr. Solution Consultant Digital Media (candidate)"
# date: today
# date-format: "dddd, D. MMMM YYYY"
# # FORMAT OPTIONS
# footer: "Joschka Schwarz - Explore new ways to create"
# ---

# %% [markdown]
# # Introduction {data-stack-name="Intro"}
#
# ## Heading 1
#
# * Text1
# * We need more
# * lines here
# * Another line
#
# ## Heading 2
#
#
# ```{html}
# <div class="section static-links l-spacing masonry-layout masonry-up" daa-lh="s6">
#         <div class="brick split light rounded-corners button-fill row media-right grid-full-width" style="background: rgb(245, 245, 245);" data-block-status="loaded" daa-lh="b1|brick">
#           <div class="foreground">
#             <div class="brick-text">
#               <h3 id="personalization-at-scale" class="heading-l">Personalization at scale</h3>
#               <p class="body-m">Modern marketers know that experience is the difference. Customers don’t just want products. They want to engage with brands in ways that feel personal, authentic, and human — even when it’s digital. We know it’s not easy to make every connection personal, but Adobe has the tools to help you succeed.</p>
#               <p class="action-area"><a href="/solutions/personalization-at-scale.html" aria-label="Learn more personalization at scale" class="con-button outline button-l" daa-ll="Learn more-1--Personalization at s">Learn more</a></p>
#             </div>
#             <div class="brick-media">
#               <picture>
#                 <source type="image/webp" srcset="./media_1f9cb9d59cf341dfdf53ce12ac34c02075253e9f7.png?width=2000&amp;format=webply&amp;optimize=medium" media="(min-width: 600px)">
#                 <source type="image/webp" srcset="./media_1f9cb9d59cf341dfdf53ce12ac34c02075253e9f7.png?width=750&amp;format=webply&amp;optimize=medium">
#                 <source type="image/png" srcset="./media_1f9cb9d59cf341dfdf53ce12ac34c02075253e9f7.png?width=2000&amp;format=png&amp;optimize=medium" media="(min-width: 600px)">
#                 <img loading="lazy" alt="" src="./media_1f9cb9d59cf341dfdf53ce12ac34c02075253e9f7.png?width=750&amp;format=png&amp;optimize=medium" width="1200" height="768">
#               </picture>
#             </div>
#           </div>
#         </div>
#         <div class="brick light rounded-corners grid-span-4" style="background: rgb(245, 245, 245);" data-block-status="loaded" daa-lh="b2|brick">
#
#           <div class="foreground">
#             <div class="brick-text">
#               <h3 id="unified-customer-experience" class="heading-m">Unified customer experience</h3>
#               <p class="body-m">Transform your customer experiences from isolated interactions into a purposeful customer journey. With Adobe, you can organize and connect your customer data using powerful journey orchestration. This gives you new insights into audience behavior — so you can continuously optimize individual experiences across every channel.</p>
#               <p class="action-area"><a href="/solutions/unified-customer-experience.html" class="con-button outline button-l" daa-ll="Learn more-1--Unified customer exp">Learn more</a></p>
#             </div>
#           </div>
#         </div>
#         <div class="brick split rounded-corners dark button-fill grid-span-8" data-block-status="loaded" daa-lh="b3|brick">
#           <div class="background">
#             <div data-align="center" data-valign="middle" class="mobile-only"><picture>
#                 <source type="image/webp" srcset="./media_1415bea645066ff94d5dce68ef15901668fbfd9ae.png?width=2000&amp;format=webply&amp;optimize=medium" media="(min-width: 600px)">
#                 <source type="image/webp" srcset="./media_1415bea645066ff94d5dce68ef15901668fbfd9ae.png?width=750&amp;format=webply&amp;optimize=medium">
#                 <source type="image/png" srcset="./media_1415bea645066ff94d5dce68ef15901668fbfd9ae.png?width=2000&amp;format=png&amp;optimize=medium" media="(min-width: 600px)">
#                 <img loading="lazy" alt="" src="./media_1415bea645066ff94d5dce68ef15901668fbfd9ae.png?width=750&amp;format=png&amp;optimize=medium" width="1584" height="867" style="object-fit: cover; object-position: center center;">
#               </picture></div>
#             <div data-align="center" data-valign="middle" class="tablet-only"><picture>
#                 <source type="image/webp" srcset="./media_1415bea645066ff94d5dce68ef15901668fbfd9ae.png?width=2000&amp;format=webply&amp;optimize=medium" media="(min-width: 600px)">
#                 <source type="image/webp" srcset="./media_1415bea645066ff94d5dce68ef15901668fbfd9ae.png?width=750&amp;format=webply&amp;optimize=medium">
#                 <source type="image/png" srcset="./media_1415bea645066ff94d5dce68ef15901668fbfd9ae.png?width=2000&amp;format=png&amp;optimize=medium" media="(min-width: 600px)">
#                 <img loading="lazy" alt="" src="./media_1415bea645066ff94d5dce68ef15901668fbfd9ae.png?width=750&amp;format=png&amp;optimize=medium" width="1584" height="867" style="object-fit: cover; object-position: center center;">
#               </picture></div>
#             <div data-align="center" data-valign="middle" class="desktop-only"><picture>
#                 <source type="image/webp" srcset="./media_13b8aa5dca19cdd998cecb707db107f22e52f4474.png?width=2000&amp;format=webply&amp;optimize=medium" media="(min-width: 600px)">
#                 <source type="image/webp" srcset="./media_13b8aa5dca19cdd998cecb707db107f22e52f4474.png?width=750&amp;format=webply&amp;optimize=medium">
#                 <source type="image/png" srcset="./media_13b8aa5dca19cdd998cecb707db107f22e52f4474.png?width=2000&amp;format=png&amp;optimize=medium" media="(min-width: 600px)">
#                 <img loading="lazy" alt="" src="./media_13b8aa5dca19cdd998cecb707db107f22e52f4474.png?width=750&amp;format=png&amp;optimize=medium" width="1584" height="866" style="object-fit: cover; object-position: center bottom;">
#               </picture></div>
#           </div>
#           <div class="foreground">
#             <div data-valign="middle" class="brick-text">
#               <h3 id="content-supply-chain" class="heading-m">Content supply chain</h3>
#               <p class="body-m">Adobe offers an end-to-end solution that helps organizations optimize their entire planning, creation, management, delivery, and optimization processes for content. Powered by AI, it lets your teams create content beyond human scale, improve marketing agility, accelerate time to market, and increase content ROI.</p>
#               <p class="action-area"><a href="/solutions/content-supply-chain.html" aria-label="Learn more content supply chain" class="con-button outline button-l" daa-ll="Learn more-1--Content supply chain">Learn more</a></p>
#             </div>
#           </div>
#         </div>
#         <div class="brick split dark rounded-corners button-fill row media-right grid-span-8" style="background: rgb(0, 0, 0);" data-block-status="loaded" daa-lh="b4|brick">
#
#           <div class="foreground">
#             <div class="brick-text">
#               <h3 id="creative-and-production-solutions-for-the-enterprise" class="heading-m">Creative and production solutions for the enterprise</h3>
#               <p class="body-m">Let teams across your organization create standout, on-brand content with greater speed, scale, and relevance. Powered by Firefly — the most comprehensive AI platform for creative content that’s safe for business use — these solutions help your organization move confidently from experimenting with AI to delivering value.</p>
#               <p class="action-area"><a href="/solutions/content-supply-chain/creation-production.html" aria-label="Learn more Creative and production solutions for the enterprise" class="con-button outline button-l" daa-ll="Learn more-1--Creative and product">Learn more</a></p>
#             </div>
#             <div class="brick-media">
#     <div class="video-container video-holder"><video playsinline="" autoplay="" muted="" loop="" data-video-source="https://business.adobe.com/media_11d46a3e56f3c5e60b829a1559337e9ca462593fc.mp4"><source src="https://business.adobe.com/media_11d46a3e56f3c5e60b829a1559337e9ca462593fc.mp4" type="video/mp4"></video>
#       <a class="pause-play-wrapper" role="button" tabindex="0" aria-pressed="true" video-index="8" aria-label="Pause motion 8" daa-ll="Pause motion 8-2--Creative and product">
#         <div class="offset-filler is-playing">
#           <img class="accessibility-control pause-icon" src="https://business.adobe.com/federal/assets/svgs/accessibility-pause.svg" alt="Pause motion">
#           <img class="accessibility-control play-icon" src="https://business.adobe.com/federal/assets/svgs/accessibility-play.svg" alt="Play motion">
#         </div>
#       </a>
#     </div>
#   </div>
#           </div>
#         </div>
#         <div class="brick light rounded-corners grid-span-4" style="background: rgb(245, 245, 245);" data-block-status="loaded" daa-lh="b5|brick">
#
#           <div class="foreground">
#             <div data-valign="middle" class="brick-text">
#               <h3 id="b2b-gtm-orchestration" class="heading-m">B2B GTM Orchestration</h3>
#               <p class="body-m">Experience Cloud lets you deliver account-based experiences that resonate with buyers and differentiate your brand. Advanced features such as real-time data, unified 360-degree profiles, buying groups, tailored journeys, and AI-driven workflows make every customer interaction relevant and let you deliver a seamless digital journey that’s directly integrated with the sales process.</p>
#               <p class="action-area"><a href="/solutions/b2b-marketing.html" aria-label="Learn more b2b gtm orchestration" class="con-button outline button-l" daa-ll="Learn more-1--B2B GTM Orchestratio">Learn more</a></p>
#             </div>
#           </div>
#         </div>
#         <div class="brick split light rounded-corners button-fill row media-right grid-full-width" style="background: rgb(245, 245, 245);" data-block-status="loaded" daa-lh="b6|brick">
#
#           <div class="foreground">
#             <div class="brick-text">
#               <h3 id="document-productivity" class="heading-l">Document productivity</h3>
#               <p class="body-m">Improve productivity and empower your teams with actionable insights from multiple documents and file types with Document Cloud, a secure, AI-powered solution that accelerates workflows. Use Acrobat AI Assistant to synthesize and analyze research studies, reports, transcripts, and more.</p>
#               <p class="action-area"><a href="https://www.adobe.com/acrobat/business/enterprise.html" target="_blank" aria-label="Learn more document productivity" class="con-button outline button-l" daa-ll="Learn more-1--Document productivit">Learn more</a></p>
#             </div>
#             <div class="brick-media">
#               <picture>
#                 <source type="image/webp" srcset="./media_1f69b41a49546186e9642dddf216d4320cdfe4790.png?width=2000&amp;format=webply&amp;optimize=medium" media="(min-width: 600px)">
#                 <source type="image/webp" srcset="./media_1f69b41a49546186e9642dddf216d4320cdfe4790.png?width=750&amp;format=webply&amp;optimize=medium">
#                 <source type="image/png" srcset="./media_1f69b41a49546186e9642dddf216d4320cdfe4790.png?width=2000&amp;format=png&amp;optimize=medium" media="(min-width: 600px)">
#                 <img loading="lazy" alt="" src="./media_1f69b41a49546186e9642dddf216d4320cdfe4790.png?width=750&amp;format=png&amp;optimize=medium" width="1200" height="769">
#               </picture>
#             </div>
#           </div>
#         </div>
#         <div class="section-metadata" data-block-status="loaded">
#           <div>
#             <div>style</div>
#             <div>static-links, l-spacing</div>
#           </div>
#           <div>
#             <div>masonry</div>
#             <div>
#               <p>Full-width</p>
#               <p>span 4, span 8</p>
#               <p>span 8, span 4</p>
#               <p>Full-width</p>
#             </div>
#           </div>
#         </div>
#       </div>
# ```
#
#
# # Methods {data-stack-name="Method"}
#
# ## Heading 1
#
# Text1
#
# ## Heading 2
#
# Text2
#
# # Results {data-stack-name="Results"}
#
# ## Heading 1
#
# Text1
#
# ## Heading 2
#
# Text2
